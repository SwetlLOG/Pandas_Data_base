# %% [markdown]
# ### Условие 1: Задача 1
# Постройте график
#
# Назовите график
#
# Сделайте именование оси x и оси y
#
# Сделайте выводы
#
# #### 1.1. Скачать следующие данные: kc-house-data и laptop_price

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('kc_house_data.csv', encoding = '1251')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# 1.2. Изучите стоимости недвижимости

# %%
df_new = df['price'].value_counts()
df_new
# Out:
# 350000.0     172
# 450000.0     172
# 550000.0     159
# 500000.0     152
# 425000.0     150
#             ...
# 607010.0       1
# 1362500.0      1
# 298800.0       1
# 957500.0       1
# 402101.0       1
# Name: price, Length: 4028, dtype: int64

# %%
df_new[df_new == df_new.max()]
# Out:
# 350000.0    172
# 450000.0    172
# Name: price, dtype: int64

# %%
df['price'].min(), df['price'].max()
# Out:
# (75000.0, 7700000.0)

# %% [markdown]
# #### В изучаемом регионе стоимость жилья варьеруется от 75 000,0 усл.ед. до 7 700 000,0 усл.ед., наибольшее количество недвижимости находится в ценовой категории от 350 000 до 450 000 усл. ед.

# %% [markdown]
# 1.3. Изучите распределение квадратуры жилой

# %%
df['sqft_living'].min(), df['sqft_living'].max()
# Out:
# (290, 13540)

# %%
plt.figure(figsize=(15,9))
plt.hist(df['sqft_living'], bins=50)
plt.title('Распределение квадратуры жилой площади')
plt.xlabel('floors')
plt.ylabel('жилая площадь');

# %% [markdown]
# #### В изучаемом регионе квадратура жилой площади в домах варьеруется от 290 кв м  до 13 540 кв м, наиболее распространена  недвижимость с жилой площадью около 2 000 кв м .

# %% [markdown]
# 1.4. Изучите распределение года постройки

# %%
df['yr_built'].min(), df['yr_built'].max()
# Out:
# (1900, 2015)

# %%
plt.figure(figsize=(10,4))
plt.hist(df['yr_built']);
plt.title('Распределение года постройки домов')
plt.xlabel('Год постройки')
plt.ylabel('Количество домов')
plt.grid();

# %% [markdown]
# #### В изучаемом регионе наибольшее количество домов построено после 2005 года.

# %% [markdown]
# Условие 2: 2 задача
# 2.1. Изучите распределение домов от наличия вида на набережную
# Постройте график
# Сделайте выводы

# %%
data = df['waterfront'].value_counts()
data
# Out:
# 0    21450
# 1      163
# Name: waterfront, dtype: int64

# %%
plt.pie(data.values, labels=data.index, autopct='%.1f%%')
plt.title('Распределение домов от наличия вида на набережную');

# %% [markdown]
# #### В изучаемом регионе только 0,8% недвижимости имеют вид на набережную

# %% [markdown]
# 2.2. Изучите распределение этажей домов

# %%
data_1 = df['floors'].value_counts()
data_1
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
plt.pie(data_1.values, labels=data_1.index, autopct='%.1f%%')
plt.title('Распределение зтажности домов');

# %% [markdown]
# #### В изучаемом регионе преобладают одно- и двухэтажные  дома ( почти 50% домов одноэтажные, почти 40% двухэтажные).

# %% [markdown]
# 2.3. Изучите распределение состояния домов

# %%
plt.figure(figsize=(10,4))
plt.hist(df['grade']);
plt.title('Распределение состояния домов')
plt.xlabel('Состояние дома')
plt.ylabel('Количество домов')
plt.grid();

# %% [markdown]
#  #### В изучаемом регионе максимальное количество домов имеют средний уровень конструкции и дизайна

# %% [markdown]
# ### Условие 3: 3 задача
# Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
# Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями

# %%
plt.figure(figsize=(10,4))
plt.bar(df['grade'],df['price']);
plt.title('Влияние состояния недвижимости на цену')
plt.xlabel('Цена')
plt.ylabel('Состояние дома')
plt.grid();

# %% [markdown]
# #### Чем выше оценка состояния дома, тем выше цена недвижимости.

# %%
plt.figure(figsize=(10,4))
plt.bar(df['yr_built'], df['price']);
plt.title('Влияние года постройки на цену')
plt.xlabel('Цена')
plt.ylabel('Год постройки')
plt.grid();

# %% [markdown]
# #### На основе проведенных исследований можно сделать вывод, что прямой зависимости от года постройки на цену недвижимости нет, больше влияет состояние дома, а также наличие вида на набережную
